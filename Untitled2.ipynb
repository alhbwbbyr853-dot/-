# %% [markdown]
# <a href="https://colab.research.google.com/github/alhbwbbyr853-dot/-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


x=[4,6,2,8]
y=[3,1,5,8]
plt.plot(x,y)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Abeer/cleaned_ratings.csv")
df.head()
# Out:
# Mounted at /content/drive
#    UserID        ISBN  Rating
# 0  276726   155061224       5
# 1  276729  052165615X       3
# 2  276729   521795028       6
# 3  276744  038550120X       7
# 4  276747    60517794       9
